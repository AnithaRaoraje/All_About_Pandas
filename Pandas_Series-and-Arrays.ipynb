# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1d Data structure - Series

# %%
a = [1,1,2,3,4]
a
# Out:
# [1, 1, 2, 3, 4]

# %%
a.index(1)
# Out:
# 0

# %%
s = pd.Series([1,2,3,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    4
# 5    5
# dtype: int64

# %%
s[0]
# Out:
# 1

# %%
s[2]
# Out:
# 3

# %%
se = pd.Series(np.linspace(10, 100, 10))
se
# Out:
# 0     10.0
# 1     20.0
# 2     30.0
# 3     40.0
# 4     50.0
# 5     60.0
# 6     70.0
# 7     80.0
# 8     90.0
# 9    100.0
# dtype: float64

# %%
ser = pd.Series(np.arange(10, 100, 7))
ser
# Out:
# 0     10
# 1     17
# 2     24
# 3     31
# 4     38
# 5     45
# 6     52
# 7     59
# 8     66
# 9     73
# 10    80
# 11    87
# 12    94
# dtype: int32

# %%
df = pd.DataFrame({"Students": ["A", "B", "C", "D"], "Marks": [10,20,30,40]})
df
# Out:
#   Students  Marks
# 0        A     10
# 1        B     20
# 2        C     30
# 3        D     40

# %%
# !pip install names

# %%
import names as nm
import random
# dir(nm)
nm.get_first_name()
# Out:
# 'Judith'

# %%
students = [nm.get_first_name() for i in range(10)]
students
# Out:
# ['Alyssa',
#  'May',
#  'Steve',
#  'Mary',
#  'Emma',
#  'Lloyd',
#  'Jimmy',
#  'Raymond',
#  'Barbara',
#  'Suzanne']

# %%
marks = [random.randint(35, 100) for i in range(10)]
marks
# Out:
# [71, 94, 90, 49, 47, 50, 80, 88, 67, 44]

# %%
class10 = pd.DataFrame({"Student_Name":students, "Marks":marks})
class10
# Out:
#   Student_Name  Marks
# 0       Alyssa     71
# 1          May     94
# 2        Steve     90
# 3         Mary     49
# 4         Emma     47
# 5        Lloyd     50
# 6        Jimmy     80
# 7      Raymond     88
# 8      Barbara     67
# 9      Suzanne     44

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    4
# 5    5
# dtype: int64

# %%
n = pd.Series(["A", "B", "C", "D", "E", "F", "G"])
n
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# 6    G
# dtype: object

# %%
df1 = pd.DataFrame({"Char": n, "Values":s})
df1
# Out:
#   Char  Values
# 0    A     1.0
# 1    B     2.0
# 2    C     3.0
# 3    D     3.0
# 4    E     4.0
# 5    F     5.0
# 6    G     NaN

# %%
df2 = pd.DataFrame(np.random.randint(10, 100, (10, 5)))
df2
# Out:
#     0   1   2   3   4
# 0  58  65  40  71  38
# 1  12  26  57  69  43
# 2  65  28  66  40  64
# 3  59  51  59  32  87
# 4  57  21  24  95  85
# 5  59  11  12  12  30
# 6  51  34  91  31  56
# 7  80  35  49  48  81
# 8  80  35  63  19  96
# 9  66  75  18  26  38

# %%
list("ABCDE")
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
df2 = pd.DataFrame(np.random.randint(10, 100, (10, 5)), columns = ["A", "B", "C", "D", "E"])
df2
# Out:
#     A   B   C   D   E
# 0  45  33  71  14  96
# 1  30  12  56  74  17
# 2  81  78  24  29  92
# 3  99  21  23  92  13
# 4  84  31  89  65  23
# 5  26  24  86  68  55
# 6  23  39  23  99  66
# 7  54  52  23  51  11
# 8  97  92  83  52  40
# 9  13  68  93  99  53

# %%
df2 = pd.DataFrame(np.random.randint(10, 100, (10, 5)), columns = list("ABCDE"))
df2
# Out:
#     A   B   C   D   E
# 0  97  74  84  74  78
# 1  87  68  37  78  33
# 2  45  43  59  19  13
# 3  65  40  79  65  16
# 4  29  14  72  26  80
# 5  31  82  54  44  93
# 6  85  99  49  61  70
# 7  45  98  86  69  20
# 8  80  78  11  52  92
# 9  47  60  31  77  36

# %%
pd.date_range(start = "2021-11-1" , periods = 10 , freq = "w")
# Out:
# DatetimeIndex(['2021-11-07', '2021-11-14', '2021-11-21', '2021-11-28',
#                '2021-12-05', '2021-12-12', '2021-12-19', '2021-12-26',
#                '2022-01-02', '2022-01-09'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
dates = pd.date_range(start = "2021-11-1" , periods = 10 , freq = "d")
dates
# Out:
# DatetimeIndex(['2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04',
#                '2021-11-05', '2021-11-06', '2021-11-07', '2021-11-08',
#                '2021-11-09', '2021-11-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2 = pd.DataFrame(np.random.randint(10, 100, (10, 5)), columns = list("ABCDE"), index = dates)
df2
# Out:
#              A   B   C   D   E
# 2021-11-01  64  85  60  80  56
# 2021-11-02  58  74  67  30  20
# 2021-11-03  21  59  61  78  90
# 2021-11-04  74  41  71  29  67
# 2021-11-05  14  47  74  90  95
# 2021-11-06  73  21  65  54  51
# 2021-11-07  62  36  72  37  27
# 2021-11-08  76  92  53  92  22
# 2021-11-09  93  42  77  34  19
# 2021-11-10  55  73  70  89  64

# %% [markdown]
# # Accessing Values from a DataFrame

# %%
students
# Out:
# ['Alyssa',
#  'May',
#  'Steve',
#  'Mary',
#  'Emma',
#  'Lloyd',
#  'Jimmy',
#  'Raymond',
#  'Barbara',
#  'Suzanne']

# %%
marks
# Out:
# [71, 94, 90, 49, 47, 50, 80, 88, 67, 44]

# %%
age = [random.randint(10, 18) for i in range(10)]
age
# Out:
# [16, 10, 13, 12, 16, 15, 14, 14, 16, 12]

# %%
locations = ["Chennai", "Blr", "Delhi", "Mumbai", "Kolkata"]*2
locations
# Out:
# ['Chennai',
#  'Blr',
#  'Delhi',
#  'Mumbai',
#  'Kolkata',
#  'Chennai',
#  'Blr',
#  'Delhi',
#  'Mumbai',
#  'Kolkata']

# %%
df1 = pd.DataFrame({"Name": students, "Marks": marks, "Age": age, "Dates": dates}, index = locations)
df1
# Out:
#             Name  Marks  Age      Dates
# Chennai   Alyssa     71   16 2021-11-01
# Blr          May     94   10 2021-11-02
# Delhi      Steve     90   13 2021-11-03
# Mumbai      Mary     49   12 2021-11-04
# Kolkata     Emma     47   16 2021-11-05
# Chennai    Lloyd     50   15 2021-11-06
# Blr        Jimmy     80   14 2021-11-07
# Delhi    Raymond     88   14 2021-11-08
# Mumbai   Barbara     67   16 2021-11-09
# Kolkata  Suzanne     44   12 2021-11-10

# %%
df = pd.DataFrame({"Name": students, "Marks": marks, "Age": age, "Location": locations}, index = dates)
df
# Out:
#                Name  Marks  Age Location
# 2021-11-01   Alyssa     71   16  Chennai
# 2021-11-02      May     94   10      Blr
# 2021-11-03    Steve     90   13    Delhi
# 2021-11-04     Mary     49   12   Mumbai
# 2021-11-05     Emma     47   16  Kolkata
# 2021-11-06    Lloyd     50   15  Chennai
# 2021-11-07    Jimmy     80   14      Blr
# 2021-11-08  Raymond     88   14    Delhi
# 2021-11-09  Barbara     67   16   Mumbai
# 2021-11-10  Suzanne     44   12  Kolkata

# %% [markdown]
# # loc and iloc

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %%
df['Name']
# Out:
# 0     Alyssa
# 1        May
# 2      Steve
# 3       Mary
# 4       Emma
# 5      Lloyd
# 6      Jimmy
# 7    Raymond
# 8    Barbara
# 9    Suzanne
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    16
# 1    10
# 2    13
# 3    12
# 4    16
# 5    15
# 6    14
# 7    14
# 8    16
# 9    12
# Name: Age, dtype: int64

# %%
df
# Out:
#                Name  Marks  Age Location
# 2021-11-01   Alyssa     71   16  Chennai
# 2021-11-02      May     94   10      Blr
# 2021-11-03    Steve     90   13    Delhi
# 2021-11-04     Mary     49   12   Mumbai
# 2021-11-05     Emma     47   16  Kolkata
# 2021-11-06    Lloyd     50   15  Chennai
# 2021-11-07    Jimmy     80   14      Blr
# 2021-11-08  Raymond     88   14    Delhi
# 2021-11-09  Barbara     67   16   Mumbai
# 2021-11-10  Suzanne     44   12  Kolkata

# %%
df.loc["2021-11-01", :]
# Out:
# Name         Alyssa
# Marks            71
# Age              16
# Location    Chennai
# Name: 2021-11-01 00:00:00, dtype: object

# %%
df.loc["2021-11-01", ['Name', "Marks"]]
# Out:
# Name     Alyssa
# Marks        71
# Name: 2021-11-01 00:00:00, dtype: object

# %%
df.loc["2021-11-01" : "2021-11-07" , :]
# Out:
#               Name  Marks  Age Location
# 2021-11-01  Alyssa     71   16  Chennai
# 2021-11-02     May     94   10      Blr
# 2021-11-03   Steve     90   13    Delhi
# 2021-11-04    Mary     49   12   Mumbai
# 2021-11-05    Emma     47   16  Kolkata
# 2021-11-06   Lloyd     50   15  Chennai
# 2021-11-07   Jimmy     80   14      Blr

# %%
df.loc["2021-11-01" : "2021-11-07" , "Name":"Age"]
# Out:
#               Name  Marks  Age
# 2021-11-01  Alyssa     71   16
# 2021-11-02     May     94   10
# 2021-11-03   Steve     90   13
# 2021-11-04    Mary     49   12
# 2021-11-05    Emma     47   16
# 2021-11-06   Lloyd     50   15
# 2021-11-07   Jimmy     80   14

# %%
df.loc[:"2021-11-05" , "Marks":]
# Out:
#             Marks  Age Location
# 2021-11-01     71   16  Chennai
# 2021-11-02     94   10      Blr
# 2021-11-03     90   13    Delhi
# 2021-11-04     49   12   Mumbai
# 2021-11-05     47   16  Kolkata

# %%
df
# Out:
#                Name  Marks  Age Location
# 2021-11-01   Alyssa     71   16  Chennai
# 2021-11-02      May     94   10      Blr
# 2021-11-03    Steve     90   13    Delhi
# 2021-11-04     Mary     49   12   Mumbai
# 2021-11-05     Emma     47   16  Kolkata
# 2021-11-06    Lloyd     50   15  Chennai
# 2021-11-07    Jimmy     80   14      Blr
# 2021-11-08  Raymond     88   14    Delhi
# 2021-11-09  Barbara     67   16   Mumbai
# 2021-11-10  Suzanne     44   12  Kolkata

# %%
df.iloc[:, :]
# Out:
#                Name  Marks  Age Location
# 2021-11-01   Alyssa     71   16  Chennai
# 2021-11-02      May     94   10      Blr
# 2021-11-03    Steve     90   13    Delhi
# 2021-11-04     Mary     49   12   Mumbai
# 2021-11-05     Emma     47   16  Kolkata
# 2021-11-06    Lloyd     50   15  Chennai
# 2021-11-07    Jimmy     80   14      Blr
# 2021-11-08  Raymond     88   14    Delhi
# 2021-11-09  Barbara     67   16   Mumbai
# 2021-11-10  Suzanne     44   12  Kolkata

# %%
df.iloc[:5, 1:]
# Out:
#             Marks  Age Location
# 2021-11-01     71   16  Chennai
# 2021-11-02     94   10      Blr
# 2021-11-03     90   13    Delhi
# 2021-11-04     49   12   Mumbai
# 2021-11-05     47   16  Kolkata

# %% [markdown]
# # Operations in Dataframe

# %%
df
# Out:
#                Name  Marks  Age Location
# 2021-11-01   Alyssa     71   16  Chennai
# 2021-11-02      May     94   10      Blr
# 2021-11-03    Steve     90   13    Delhi
# 2021-11-04     Mary     49   12   Mumbai
# 2021-11-05     Emma     47   16  Kolkata
# 2021-11-06    Lloyd     50   15  Chennai
# 2021-11-07    Jimmy     80   14      Blr
# 2021-11-08  Raymond     88   14    Delhi
# 2021-11-09  Barbara     67   16   Mumbai
# 2021-11-10  Suzanne     44   12  Kolkata

# %%
df = pd.read_csv("cars.csv")

# %%
df
# Out:
#     S.No                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df = pd.read_excel("D:\\BI\\Sales.xlsx")

# %%
df = pd.read_excel("D:/BI/Sales.xlsx")

# %%
# r - Raw String Literal
df = pd.read_excel(r"D:\BI\Sales.xlsx")

# %%
df.columns
# Out:
# Index(['S.No', 'model', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
# First 5 Rows
df.head()
# Out:
#    S.No              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
df.head(2)
# Out:
#    S.No          model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1      Mazda RX4  21.0    6  160.0  110   3.9  2.620  16.46   0   1
# 1     2  Mazda RX4 Wag  21.0    6  160.0  110   3.9  2.875  17.02   0   1
#
#    gear  carb
# 0     4     4
# 1     4     4

# %%
# Last 5 rows
df.tail()
# Out:
#     S.No           model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  \
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1
# 29    30    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1
#
#     gear  carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.tail(2)
# Out:
#     S.No          model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  \
# 30    31  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1
# 31    32     Volvo 142E  21.4    4  121.0  109  4.11  2.78  18.6   1   1
#
#     gear  carb
# 30     5     8
# 31     4     2

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'PropertyID', 'ProductID', 'Quantity',
#        'ProductName', 'ProductCategory', 'Price', 'PropertyCity',
#        'PropertyState', 'sales'],
#       dtype='object')

# %%
df.iloc[20, :]
# Out:
# OrderID                           1590
# OrderDate          2015-08-21 00:00:00
# PropertyID                          17
# ProductID                           93
# Quantity                             1
# ProductName                   Terminal
# ProductCategory           Public Areas
# Price                               85
# PropertyCity                 Las Vegas
# PropertyState                   Nevada
# sales                               85
# Name: 20, dtype: object

# %%
# pyodbc

# %%
df.dtypes
# Out:
# OrderID                     int64
# OrderDate          datetime64[ns]
# PropertyID                  int64
# ProductID                   int64
# Quantity                    int64
# ProductName                object
# ProductCategory            object
# Price                       int64
# PropertyCity               object
# PropertyState              object
# sales                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          5000 non-null   int64
#  1   OrderDate        5000 non-null   datetime64[ns]
#  2   PropertyID       5000 non-null   int64
#  3   ProductID        5000 non-null   int64
#  4   Quantity         5000 non-null   int64
#  5   ProductName      5000 non-null   object
#  6   ProductCategory  5000 non-null   object
#  7   Price            5000 non-null   int64
#  8   PropertyCity     5000 non-null   object
#  9   PropertyState    5000 non-null   object
#  10  sales            5000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(4)
# memory usage: 429.8+ KB

# %%
df.shape
# Out:
# (5000, 11)

# %%
df.describe()
# Out:
#            OrderID   PropertyID    ProductID     Quantity        Price  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean   2500.500000    10.541400    47.162600     2.019200    52.919000
# std    1443.520003     5.719478    27.355004     0.811519    57.552297
# min       1.000000     1.000000     1.000000     1.000000     3.000000
# 25%    1250.750000     6.000000    23.000000     1.000000    17.000000
# 50%    2500.500000    11.000000    47.000000     2.000000    30.000000
# 75%    3750.250000    15.000000    70.000000     3.000000    75.000000
# max    5000.000000    20.000000    94.000000     3.000000   300.000000
#
#              sales
# count  5000.000000
# mean    106.695800
# std     131.575007
# min       3.000000
# 25%      27.000000
# 50%      60.000000
# 75%     120.000000
# max     900.000000

# %%
df.size
# Out:
# 55000

# %%
df.nunique()
# Out:
# OrderID            5000
# OrderDate           731
# PropertyID           20
# ProductID            94
# Quantity              3
# ProductName          94
# ProductCategory       5
# Price                48
# PropertyCity         20
# PropertyState        18
# sales               112
# dtype: int64

# %%
df['PropertyCity'].nunique()
# Out:
# 20

# %%
df.head()
# Out:
#    OrderID  OrderDate  PropertyID  ProductID  Quantity       ProductName  \
# 0        1 2015-01-01          17         41         1      Office Chair
# 1      163 2015-01-25          17         41         2      Office Chair
# 2     1598 2015-08-22          17         41         3      Office Chair
# 3     4155 2016-08-20          17         41         2      Office Chair
# 4     1109 2015-06-15          17         54         2  Chest of Drawers
#
#   ProductCategory  Price PropertyCity PropertyState  sales
# 0     Furnishings     85    Las Vegas        Nevada     85
# 1     Furnishings     85    Las Vegas        Nevada    170
# 2     Furnishings     85    Las Vegas        Nevada    255
# 3     Furnishings     85    Las Vegas        Nevada    170
# 4     Furnishings    150    Las Vegas        Nevada    300

# %%
df.index = df['OrderID']

# %%
df.head()
# Out:
#          OrderID  OrderDate  PropertyID  ProductID  Quantity  \
# OrderID
# 1              1 2015-01-01          17         41         1
# 163          163 2015-01-25          17         41         2
# 1598        1598 2015-08-22          17         41         3
# 4155        4155 2016-08-20          17         41         2
# 1109        1109 2015-06-15          17         54         2
#
#               ProductName ProductCategory  Price PropertyCity PropertyState  \
# OrderID
# 1            Office Chair     Furnishings     85    Las Vegas        Nevada
# 163          Office Chair     Furnishings     85    Las Vegas        Nevada
# 1598         Office Chair     Furnishings     85    Las Vegas        Nevada
# 4155         Office Chair     Furnishings     85    Las Vegas        Nevada
# 1109     Chest of Drawers     Furnishings    150    Las Vegas        Nevada
#
#          sales
# OrderID
# 1           85
# 163        170
# 1598       255
# 4155       170
# 1109       300

# %%
df.head(2)
# Out:
#          OrderID  OrderDate  PropertyID  ProductID  Quantity   ProductName  \
# OrderID
# 1              1 2015-01-01          17         41         1  Office Chair
# 163          163 2015-01-25          17         41         2  Office Chair
#
#         ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# 1           Furnishings     85    Las Vegas        Nevada     85
# 163         Furnishings     85    Las Vegas        Nevada    170

# %%
df.drop(columns = "OrderID", inplace = True)
df.head(2)
# Out:
#          OrderDate  PropertyID  ProductID  Quantity   ProductName  \
# OrderID
# 1       2015-01-01          17         41         1  Office Chair
# 163     2015-01-25          17         41         2  Office Chair
#
#         ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# 1           Furnishings     85    Las Vegas        Nevada     85
# 163         Furnishings     85    Las Vegas        Nevada    170

# %%
df.drop(columns = ["PropertyID", "OrderDate"])
# Out:
#          ProductID  Quantity          ProductName  ProductCategory  Price  \
# OrderID
# 1               41         1         Office Chair      Furnishings     85
# 163             41         2         Office Chair      Furnishings     85
# 1598            41         3         Office Chair      Furnishings     85
# 4155            41         2         Office Chair      Furnishings     85
# 1109            54         2     Chest of Drawers      Furnishings    150
# ...            ...       ...                  ...              ...    ...
# 4347            43         1           Table Lamp      Furnishings     38
# 4275            76         3                Ficus     Public Areas     80
# 765             26         1  Envelopes (Catalog)  Office Supplies     13
# 1034            26         2  Envelopes (Catalog)  Office Supplies     13
# 4990            32         1            Note Pads  Office Supplies     14
#
#         PropertyCity PropertyState  sales
# OrderID
# ...

# %%
df.drop(index = 1109, inplace = True)
# Out:
#          OrderDate  PropertyID  ProductID  Quantity          ProductName  \
# OrderID
# 1       2015-01-01          17         41         1         Office Chair
# 163     2015-01-25          17         41         2         Office Chair
# 1598    2015-08-22          17         41         3         Office Chair
# 4155    2016-08-20          17         41         2         Office Chair
# 2759    2016-02-06          17         54         2     Chest of Drawers
# ...            ...         ...        ...       ...                  ...
# 4347    2016-09-16          10         43         1           Table Lamp
# 4275    2016-09-06          10         76         3                Ficus
# 765     2015-04-26          10         26         1  Envelopes (Catalog)
# 1034    2015-06-03          10         26         2  Envelopes (Catalog)
# 4990    2016-12-30          10         32         1            Note Pads
#
#          ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# ...

# %%
df.columns
# Out:
# Index(['OrderDate', 'PropertyID', 'ProductID', 'Quantity', 'ProductName',
#        'ProductCategory', 'Price', 'PropertyCity', 'PropertyState', 'sales'],
#       dtype='object')

# %%
df.value_counts(['PropertyCity'])
# Out:
# PropertyCity
# Philadelphia     272
# Kansas City      267
# Los Angeles      262
# Las Vegas        261
# New Orleans      260
# Nashville        257
# Seattle          257
# Chicago          257
# Richmond         256
# Cincinnati       254
# Atlanta          253
# Dallas           252
# Arlington        248
# San Francisco    243
# Orlando          238
# Boston           237
# Denver           235
# Phoenix          233
# Portland         231
# New York         227
# dtype: int64

# %%
df.head()
# Out:
#          OrderDate  PropertyID  ProductID  Quantity       ProductName  \
# OrderID
# 1       2015-01-01          17         41         1      Office Chair
# 163     2015-01-25          17         41         2      Office Chair
# 1598    2015-08-22          17         41         3      Office Chair
# 4155    2016-08-20          17         41         2      Office Chair
# 1109    2015-06-15          17         54         2  Chest of Drawers
#
#         ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# 1           Furnishings     85    Las Vegas        Nevada     85
# 163         Furnishings     85    Las Vegas        Nevada    170
# 1598        Furnishings     85    Las Vegas        Nevada    255
# 4155        Furnishings     85    Las Vegas        Nevada    170
# 1109        Furnishings    150    Las Vegas        Nevada    300

# %%
df.groupby("ProductCategory")["sales"].mean()
# Out:
# ProductCategory
# Furnishings        165.836988
# Housekeeping        47.425212
# Maintenance        116.386816
# Office Supplies     44.503012
# Public Areas       120.868302
# Name: sales, dtype: float64

# %%
df.groupby("ProductCategory")["sales"].sum()
# Out:
# ProductCategory
# Furnishings        226865
# Housekeeping        50413
# Maintenance         93575
# Office Supplies     29550
# Public Areas       133076
# Name: sales, dtype: int64

# %%
df.groupby("ProductCategory")["sales"].sum()[1:2]
# Out:
# ProductCategory
# Housekeeping    50413
# Name: sales, dtype: int64

# %%
df.groupby("ProductCategory")["sales"].min()
# Out:
# ProductCategory
# Furnishings        5
# Housekeeping       3
# Maintenance        8
# Office Supplies    3
# Public Areas       3
# Name: sales, dtype: int64

# %%
df.groupby("ProductCategory")["sales"].max()
# Out:
# ProductCategory
# Furnishings        900
# Housekeeping       120
# Maintenance        606
# Office Supplies    255
# Public Areas       645
# Name: sales, dtype: int64

# %%
df.groupby("ProductCategory")["sales"].std()
# Out:
# ProductCategory
# Furnishings        168.758678
# Housekeeping        32.815667
# Maintenance        152.124771
# Office Supplies     47.678916
# Public Areas       116.748439
# Name: sales, dtype: float64

# %%
df.groupby("ProductCategory")["sales"].var()
# Out:
# ProductCategory
# Furnishings        28479.491330
# Housekeeping        1076.867989
# Maintenance        23141.946078
# Office Supplies     2273.279026
# Public Areas       13630.198094
# Name: sales, dtype: float64

# %%
df.groupby("ProductCategory")['ProductCategory'].count()
# Out:
# ProductCategory
# Furnishings        1368
# Housekeeping       1063
# Maintenance         804
# Office Supplies     664
# Public Areas       1101
# Name: ProductCategory, dtype: int64

# %%
df.groupby(["ProductCategory", 'PropertyCity'])['sales'].mean()
# Out:
# ProductCategory  PropertyCity
# Furnishings      Arlington        179.393939
#                  Atlanta          155.636364
#                  Boston           171.492958
#                  Chicago          168.537313
#                  Cincinnati       170.352941
#                                      ...
# Public Areas     Phoenix           97.439024
#                  Portland         121.549020
#                  Richmond          99.301887
#                  San Francisco    112.706897
#                  Seattle          119.625000
# Name: sales, Length: 100, dtype: float64

# %%
df.columns
# Out:
# Index(['OrderDate', 'PropertyID', 'ProductID', 'Quantity', 'ProductName',
#        'ProductCategory', 'Price', 'PropertyCity', 'PropertyState', 'sales'],
#       dtype='object')

# %%
df.groupby("ProductCategory")['sales'].mean()
# Out:
# ProductCategory
# Furnishings        165.836988
# Housekeeping        47.425212
# Maintenance        116.386816
# Office Supplies     44.503012
# Public Areas       120.868302
# Name: sales, dtype: float64

# %%
df.head()
# Out:
#          OrderDate  PropertyID  ProductID  Quantity       ProductName  \
# OrderID
# 1       2015-01-01          17         41         1      Office Chair
# 163     2015-01-25          17         41         2      Office Chair
# 1598    2015-08-22          17         41         3      Office Chair
# 4155    2016-08-20          17         41         2      Office Chair
# 1109    2015-06-15          17         54         2  Chest of Drawers
#
#         ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# 1           Furnishings     85    Las Vegas        Nevada     85
# 163         Furnishings     85    Las Vegas        Nevada    170
# 1598        Furnishings     85    Las Vegas        Nevada    255
# 4155        Furnishings     85    Las Vegas        Nevada    170
# 1109        Furnishings    150    Las Vegas        Nevada    300

# %%
df.sort_index()
# Out:
#          OrderDate  PropertyID  ProductID  Quantity       ProductName  \
# OrderID
# 1       2015-01-01          17         41         1      Office Chair
# 2       2015-01-01          15         54         2  Chest of Drawers
# 3       2015-01-01           5         71         2            Hammer
# 4       2015-01-01          19          3         2         Washcloth
# 5       2015-01-01          12         45         3     Computer Desk
# ...            ...         ...        ...       ...               ...
# 4996    2016-12-31           3         47         2      Swivel Chair
# 4997    2016-12-31          12         57         1   Wireless Router
# 4998    2016-12-31           7         77         1    Large Area Rug
# 4999    2016-12-31          17         57         1   Wireless Router
# 5000    2016-12-31           1          9         2           Tissues
#
#         ProductCategory  Price PropertyCity  PropertyState  sales
# OrderID
# ...

# %%
df.sort_index(ascending = False)
# Out:
#          OrderDate  PropertyID  ProductID  Quantity       ProductName  \
# OrderID
# 5000    2016-12-31           1          9         2           Tissues
# 4999    2016-12-31          17         57         1   Wireless Router
# 4998    2016-12-31           7         77         1    Large Area Rug
# 4997    2016-12-31          12         57         1   Wireless Router
# 4996    2016-12-31           3         47         2      Swivel Chair
# ...            ...         ...        ...       ...               ...
# 5       2015-01-01          12         45         3     Computer Desk
# 4       2015-01-01          19          3         2         Washcloth
# 3       2015-01-01           5         71         2            Hammer
# 2       2015-01-01          15         54         2  Chest of Drawers
# 1       2015-01-01          17         41         1      Office Chair
#
#         ProductCategory  Price PropertyCity  PropertyState  sales
# OrderID
# ...

# %%
df.groupby("ProductCategory")['sales'].mean().sort_index()
# Out:
# ProductCategory
# Furnishings        165.836988
# Housekeeping        47.425212
# Maintenance        116.386816
# Office Supplies     44.503012
# Public Areas       120.868302
# Name: sales, dtype: float64

# %%
df.groupby("ProductCategory")['sales'].mean().sort_values(ascending = False)
# Out:
# ProductCategory
# Furnishings        165.836988
# Public Areas       120.868302
# Maintenance        116.386816
# Housekeeping        47.425212
# Office Supplies     44.503012
# Name: sales, dtype: float64

# %%
df.head()
# Out:
#          OrderDate  PropertyID  ProductID  Quantity       ProductName  \
# OrderID
# 1       2015-01-01          17         41         1      Office Chair
# 163     2015-01-25          17         41         2      Office Chair
# 1598    2015-08-22          17         41         3      Office Chair
# 4155    2016-08-20          17         41         2      Office Chair
# 1109    2015-06-15          17         54         2  Chest of Drawers
#
#         ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# 1           Furnishings     85    Las Vegas        Nevada     85
# 163         Furnishings     85    Las Vegas        Nevada    170
# 1598        Furnishings     85    Las Vegas        Nevada    255
# 4155        Furnishings     85    Las Vegas        Nevada    170
# 1109        Furnishings    150    Las Vegas        Nevada    300

# %%
df.sort_values(by = 'ProductName')
# Out:
#          OrderDate  PropertyID  ProductID  Quantity        ProductName  \
# OrderID
# 304     2015-02-17           8         67         1  Adjustable Wrench
# 3691    2016-06-12           7         67         2  Adjustable Wrench
# 2636    2016-01-20          20         67         2  Adjustable Wrench
# 2294    2015-12-01           9         67         1  Adjustable Wrench
# 2947    2016-03-05           4         67         3  Adjustable Wrench
# ...            ...         ...        ...       ...                ...
# 1252    2015-07-06          18         66         2          Wood Glue
# 1476    2015-08-08           5         66         2          Wood Glue
# 2048    2015-10-28           5         66         1          Wood Glue
# 1987    2015-10-17           9         66         1          Wood Glue
# 4895    2016-12-13          13         66         3          Wood Glue
#
#         ProductCategory  Price   PropertyCity  PropertyState  sales
# OrderID
# ...

# %%
df.sort_values(by = 'ProductName', ascending = False)
# Out:
#          OrderDate  PropertyID  ProductID  Quantity        ProductName  \
# OrderID
# 1699    2015-09-06           4         66         1          Wood Glue
# 1849    2015-09-29           1         66         1          Wood Glue
# 828     2015-05-05          11         66         3          Wood Glue
# 3100    2016-03-25          14         66         3          Wood Glue
# 1054    2015-06-05          14         66         1          Wood Glue
# ...            ...         ...        ...       ...                ...
# 933     2015-05-21          11         67         2  Adjustable Wrench
# 132     2015-01-22          11         67         3  Adjustable Wrench
# 84      2015-01-14          11         67         2  Adjustable Wrench
# 4438    2016-10-02          12         67         2  Adjustable Wrench
# 372     2015-02-26           9         67         2  Adjustable Wrench
#
#         ProductCategory  Price PropertyCity PropertyState  sales
# OrderID
# ...

# %%
df.groupby("ProductCategory")['sales'].mean().sort_values(ascending = False)

# %%
pd.set_option('display.max_rows', 1000)
df.groupby(["ProductCategory", 'PropertyCity'])['sales'].mean().sort_values(ascending = False)
# Out:
# ProductCategory  PropertyCity
# Furnishings      Dallas           197.177419
#                  Nashville        188.410959
#                  Phoenix          180.086957
#                  Arlington        179.393939
#                  Los Angeles      177.435484
#                  Kansas City      176.750000
#                  Las Vegas        175.677966
#                  Boston           171.492958
#                  Cincinnati       170.352941
#                  Chicago          168.537313
#                  Philadelphia     168.515625
#                  San Francisco    166.657534
#                  Orlando          163.632911
#                  Portland         158.953846
#                  Denver           157.925373
#                  Atlanta          155.636364
#                  Seattle          151.695652
# Maintenance      Denver           145.433333
# Public Areas     Cincinnati       145.089286
#                  Orlando          144.454545
# ...

# %%
products = pd.read_excel(r'D:\BI\PropertyOrderProduct.xlsx', sheet_name = "Products")
products.head(2)
# Out:
#    ProductID  ProductName ProductCategory  Price
# 0          1  Large Towel    Housekeeping      9
# 1          2   Hand Towel    Housekeeping      5

# %%
orders = pd.read_excel(r'D:\BI\PropertyOrderProduct.xlsx')
orders.head(2)
# Out:
#    PropertyID PropertyCity PropertyState
# 0           1     New York      New York
# 1           2   Cincinnati          Ohio

# %%
products, propertyinfo = pd.read_excel(r'D:\BI\PropertyOrderProduct.xlsx', sheet_name = ["Products", "PropertyInfo"])
